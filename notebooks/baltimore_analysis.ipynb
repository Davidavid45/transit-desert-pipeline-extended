# %% [markdown]
# # Transit Desert Analysis: Baltimore City
#
# Interactive exploration of transit desert analysis results.
#
# **Run the pipeline first:** `python run_pipeline.py`

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

try:
    import folium
    FOLIUM_AVAILABLE = True
except ImportError:
    FOLIUM_AVAILABLE = False

plt.style.use('seaborn-v0_8-whitegrid')
PROJECT_ROOT = Path('.').parent if Path('.').name == 'notebooks' else Path('.')
DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
print(f"Data directory: {DATA_DIR.resolve()}")
# Out:
# Data directory: /Users/oluwasegunadegoke/Desktop/Projects/Transit_Dessert/transit-desert-pipeline-extended/notebooks/data/processed

# %%
gpd.read_file("/Users/oluwasegunadegoke/Desktop/Projects/Transit_Dessert/transit-desert-pipeline-extended/data/processed/demand_metrics.gpkg")
# Out:
#     STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 0        24      510  280301  24510280301  2803.01  Census Tract 2803.01
# 1        24      510  240300  24510240300     2403     Census Tract 2403
# 2        24      510  250101  24510250101  2501.01  Census Tract 2501.01
# 3        24      510  250102  24510250102  2501.02  Census Tract 2501.02
# 4        24      510  250103  24510250103  2501.03  Census Tract 2501.03
# ..      ...      ...     ...          ...      ...                   ...
# 194      24      510  271600  24510271600     2716     Census Tract 2716
# 195      24      510  271700  24510271700     2717     Census Tract 2717
# 196      24      510  230100  24510230100     2301     Census Tract 2301
# 197      24      510  140100  24510140100     1401     Census Tract 1401
# 198      24      510  272007  24510272007  2720.07  Census Tract 2720.07
#
#      MTFCC FUNCSTAT    ALAND  AWATER  ... pct_elderly pct_youth  \
# 0    G5020        S  3160921   20250  ...    0.146832  0.154037
# 1    G5020        S   200576       0  ...    0.089114  0.112405
# 2    G5020        S   962784       0  ...    0.136946  0.277094
# 3    G5020        S   737636       0  ...    0.111757  0.247416
# 4    G5020        S  2587957       0  ...    0.290974  0.119062
# ..     ...      ...      ...     ...  ...         ...       ...
# 194  G5020        S   850296       0  ...    0.193814  0.287887
# 195  G5020        S  1734101       0  ...    0.232428  0.246442
# 196  G5020        S   336352       0  ...    0.060161  0.181904
# 197  G5020        S   566966       0  ...    0.232287  0.047236
# 198  G5020        S   802298       0  ...    0.123073  0.258859
#
#      z_pct_zero_vehicle  z_pct_poverty  z_pct_minority  z_pct_elderly  \
# 0              0.066686      -0.494329        0.630083       0.021856
# 1             -0.934982      -1.279227       -2.034800      -0.801639
# 2             -0.535035      -0.734417        0.787865      -0.119199
# 3             -0.005322      -0.595671        0.703987      -0.478578
# 4              0.349434      -0.210525       -1.017766       2.078390
# ..                  ...            ...             ...            ...
# 194           -0.186996       0.394057        0.759537       0.692172
# 195           -0.018458      -0.020767        0.659142       1.243086
# 196           -1.205579      -0.757691       -1.115161      -1.214722
# 197            0.268567      -0.484820       -1.027122       1.241071
# 198           -0.040180       0.064074       -0.309566      -0.317132
#
#      z_pct_youth       TDI  TDI_normalized  \
# 0      -0.545169 -0.028798       43.657872
# 1      -1.043049 -1.231812        7.280517
# 2       0.926465 -0.111775       41.148784
# 3       0.571550 -0.024349       43.792429
# 4      -0.963442  0.064060       46.465783
# ..           ...       ...             ...
# 194     1.055539  0.403703       56.736064
# 195     0.559907  0.363553       55.522000
# 196    -0.211906 -0.977528       14.969698
# 197    -1.822409 -0.242140       37.206750
# 198     0.708392 -0.034679       43.480043
#
#                                               geometry
# 0    POLYGON ((1394001.144 602575.371, 1394063.303 ...
# 1    POLYGON ((1421991.881 587393.114, 1422312.263 ...
# 2    POLYGON ((1394150.809 586936.663, 1394226.558 ...
# 3    POLYGON ((1398459.43 586920.796, 1398468.931 5...
# 4    POLYGON ((1397998.358 584933.465, 1398399.372 ...
# ..                                                 ...
# 194  POLYGON ((1404661.997 610234.09, 1404675.983 6...
# 195  POLYGON ((1401925.332 613898.55, 1401945.927 6...
# 196  POLYGON ((1419647.994 585815.609, 1419663.646 ...
# 197  POLYGON ((1416051.901 598827.46, 1416172.975 5...
# 198  POLYGON ((1393898.859 619096.269, 1393899.073 ...
#
# [199 rows x 25 columns]

# %%
# Use .resolve() or Path.cwd() to get the actual folder name
current_path = Path('.').resolve()

if current_path.name == 'notebooks':
    PROJECT_ROOT = current_path.parent
else:
    PROJECT_ROOT = current_path

DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
print(f"Corrected Data directory: {DATA_DIR}")
# Out:
# Corrected Data directory: /Users/oluwasegunadegoke/Desktop/Projects/Identifying_Transit_Deserts/transit-desert-pipeline/data/processed

# %% [markdown]
# ## 1. Load Data

# %%
gdf = gpd.read_file(DATA_DIR.resolve() / 'transit_deserts.gpkg') 
print(f"Loaded {len(gdf)} Census tracts")
gdf[['CPTA_normalized', 'TDI_normalized', 'transit_gap', 'classification_simple']].head(10)
# Out:
# Loaded 408 Census tracts
#    CPTA_normalized  TDI_normalized  transit_gap classification_simple
# 0        37.508086       43.065230     5.557144           Underserved
# 1        40.696787       27.093996   -13.602790           Well-Served
# 2        36.104937       50.484595    14.379658        Transit Desert
# 3        35.126334       32.791486    -2.334848           Underserved
# 4        33.453571       77.692407    44.238837        Transit Desert
# 5        47.142912       53.018159     5.875246      Transit Stressed
# 6        44.003146       60.282851    16.279705      Transit Stressed
# 7        37.210784       36.951809    -0.258975           Underserved
# 8        34.671020       29.348810    -5.322210           Underserved
# 9        36.918754       56.586612    19.667858        Transit Desert

# %% [markdown]
# ## 2. Classification Summary

# %%
print("Transit Desert Classification:")
print(gdf['classification_simple'].value_counts())
print(f"\nTotal Transit Deserts: {gdf['transit_desert'].sum()}")
# Out:
# Transit Desert Classification:
# classification_simple
# Underserved         130
# Transit Stressed    130
# Well-Served          74
# Transit Desert       74
# Name: count, dtype: int64
#
# Total Transit Deserts: 128

# %% [markdown]
# ## 3. Supply vs Demand Scatter

# %%
colors = {'Transit Desert': '#d73027', 'Transit Stressed': '#fc8d59', 
          'Underserved': '#fee090', 'Well-Served': '#91bfdb'}

fig, ax = plt.subplots(figsize=(10, 8))
for cat, color in colors.items():
    subset = gdf[gdf['classification_simple'] == cat]
    ax.scatter(subset['CPTA_normalized'], subset['TDI_normalized'], 
               c=color, label=f"{cat} ({len(subset)})", alpha=0.7, s=50)

ax.axvline(gdf['CPTA_normalized'].median(), color='gray', linestyle='--', alpha=0.5)
ax.axhline(gdf['TDI_normalized'].median(), color='gray', linestyle='--', alpha=0.5)
ax.set_xlabel('Transit Supply (CPTA)')
ax.set_ylabel('Transit Demand (TDI)')
ax.set_title('Supply vs Demand by Census Tract')
ax.legend()
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
plt.show()

# %% [markdown]
# ## 4. Maps

# %%
import gtfs_kit as gk
from pathlib import Path

gtfs_dir = Path("../data/raw/gtfs")
print(f"Looking in: {gtfs_dir.resolve()}")
print(f"Exists: {gtfs_dir.exists()}")

if gtfs_dir.exists():
    zips = sorted(gtfs_dir.glob("*.zip"))
    print(f"Found {len(zips)} zip files")
    
    for z in zips:
        print(f"\n--- {z.name} ---")
        feed = gk.read_feed(z, dist_units='mi')
        
        if feed.calendar is not None and len(feed.calendar) > 0:
            print(f"  calendar.txt: {len(feed.calendar)} rows")
            print(f"    start: {feed.calendar['start_date'].min()} to {feed.calendar['start_date'].max()}")
            print(f"    end: {feed.calendar['end_date'].min()} to {feed.calendar['end_date'].max()}")
        else:
            print("  calendar.txt: EMPTY")
        
        if feed.calendar_dates is not None and len(feed.calendar_dates) > 0:
            print(f"  calendar_dates.txt: {len(feed.calendar_dates)} rows")
            print(f"    dates: {feed.calendar_dates['date'].min()} to {feed.calendar_dates['date'].max()}")
        else:
            print("  calendar_dates.txt: EMPTY")
        
        print(f"  stops: {len(feed.stops)}, stop_times: {len(feed.stop_times)}")
else:
    print("Directory not found! Try: Path('../data/raw/gtfs') or check your working directory")
    import os
    print(f"Current dir: {os.getcwd()}")
# Out:
# Looking in: /Users/oluwasegunadegoke/Desktop/Projects/Transit_Dessert/transit-desert-pipeline-extended/data/raw/gtfs
# Exists: True
# Found 3 zip files
#
# --- gtfs_1.zip ---
#   calendar.txt: 3 rows
#     start: 20260208 to 20260208
#     end: 20260613 to 20260613
#   calendar_dates.txt: 10 rows
#     dates: 20250901 to 20260525
#   stops: 4047, stop_times: 700258
#
# --- gtfs_2.zip ---
#   calendar.txt: 2 rows
#     start: 20240101 to 20240101
#     end: 20261231 to 20261231
#   calendar_dates.txt: 40 rows
#     dates: 20240101 to 20261225
#   stops: 239, stop_times: 5348
#
# --- gtfs_3.zip ---
#   calendar.txt: 6 rows
#     start: 20230423 to 20260116
#     end: 20260119 to 20261231
#   calendar_dates.txt: 4 rows
#     dates: 20260116 to 20260117
#   stops: 161, stop_times: 23456

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

gdf.plot(column='CPTA_normalized', cmap='RdYlBu', legend=True, ax=axes[0])
axes[0].set_title('Transit Supply (CPTA)')
axes[0].set_axis_off()

gdf.plot(column='TDI_normalized', cmap='RdYlBu_r', legend=True, ax=axes[1])
axes[1].set_title('Transit Demand (TDI)')
axes[1].set_axis_off()

plt.tight_layout()
plt.show()

# %%
# Classification map
fig, ax = plt.subplots(figsize=(12, 10))
for cat, color in colors.items():
    gdf[gdf['classification_simple'] == cat].plot(color=color, ax=ax, label=cat)
ax.set_title('Transit Desert Classification')
ax.legend()
ax.set_axis_off()
plt.show()
# Out:
# /var/folders/g5/s9j4vt_n7k38gs24fcm_lpj40000gn/T/ipykernel_80916/1306407364.py:6: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()
# /var/folders/g5/s9j4vt_n7k38gs24fcm_lpj40000gn/T/ipykernel_80916/1306407364.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ## 5. Equity Analysis

# %%
deserts = gdf[gdf['transit_desert'] == True]
non_deserts = gdf[gdf['transit_desert'] == False]

metrics = ['pct_zero_vehicle', 'pct_poverty', 'pct_minority', 'pct_elderly']
comparison = pd.DataFrame({
    'Transit Deserts': [deserts[m].mean() for m in metrics],
    'Non-Deserts': [non_deserts[m].mean() for m in metrics]
}, index=['Zero-Vehicle HH', 'Below Poverty', 'Minority Pop', 'Elderly 65+'])

comparison['Difference'] = comparison['Transit Deserts'] - comparison['Non-Deserts']
print(comparison.round(3) * 100)
# Out:
#                  Transit Deserts  Non-Deserts  Difference
# Zero-Vehicle HH             40.1         21.4        18.7
# Below Poverty               33.7         15.5        18.2
# Minority Pop                86.1         50.9        35.2
# Elderly 65+                 14.3         13.8         0.5

# %%
# Equity bar chart
comparison[['Transit Deserts', 'Non-Deserts']].plot(kind='bar', figsize=(10, 6))
plt.title('Demographic Comparison: Transit Deserts vs Non-Deserts')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. LISA Clusters

# %%
print("LISA Cluster Counts:")
print(gdf['lisa_cluster'].value_counts())
# Out:
# LISA Cluster Counts:
# lisa_cluster
# Not Significant    265
# High-High           75
# Low-Low             58
# High-Low             5
# Low-High             5
# Name: count, dtype: int64

# %%
lisa_colors = {'High-High': '#d7191c', 'Low-Low': '#2c7bb6', 'High-Low': '#fdae61',
               'Low-High': '#abd9e9', 'Not Significant': '#eeeeee'}

fig, ax = plt.subplots(figsize=(12, 10))
for cluster, color in lisa_colors.items():
    subset = gdf[gdf['lisa_cluster'] == cluster]
    if len(subset) > 0:
        subset.plot(color=color, ax=ax, label=f"{cluster} ({len(subset)})")

ax.set_title('LISA Clusters (Transit Gap)')
ax.legend(loc='lower right')
ax.set_axis_off()
plt.show()
# Out:
# /var/folders/g5/s9j4vt_n7k38gs24fcm_lpj40000gn/T/ipykernel_80916/2742794918.py:11: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend(loc='lower right')
# /var/folders/g5/s9j4vt_n7k38gs24fcm_lpj40000gn/T/ipykernel_80916/2742794918.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')

# %% [markdown]
# ## 7. Interactive Map (Folium)

# %%
if FOLIUM_AVAILABLE:
    # Create interactive map
    gdf_wgs84 = gdf.to_crs('EPSG:4326')
    center = [gdf_wgs84.geometry.centroid.y.mean(), gdf_wgs84.geometry.centroid.x.mean()]
    
    m = folium.Map(location=center, zoom_start=11, tiles='CartoDB positron')
    
    # Add choropleth
    folium.Choropleth(
        geo_data=gdf_wgs84.__geo_interface__,
        data=gdf_wgs84,
        columns=['GEOID', 'transit_gap'],
        key_on='feature.properties.GEOID',
        fill_color='RdYlBu_r',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='Transit Gap'
    ).add_to(m)
    
    display(m)
else:
    print("Install folium for interactive maps: pip install folium")
# Out:
# /var/folders/g5/s9j4vt_n7k38gs24fcm_lpj40000gn/T/ipykernel_80916/4091883790.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [gdf_wgs84.geometry.centroid.y.mean(), gdf_wgs84.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e77009a32ac5a473b6493e515285836 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e77009a32ac5a473b6493e515285836&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e77009a32ac5a473b6493e515285836 = L.map(
#                 &quot;map_3e77009a32ac5a473b6493e515285836&quot;,
#                 {
#                     center: [39.998681248903594, -75.14854413247001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bf4879161b2c6428ef245676e093157 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bf4879161b2c6428ef245676e093157.addTo(map_3e77009a32ac5a473b6493e515285836);
#
#
#             var choropleth_1724ddf107963f2ee323882a6e5ba3c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_5eda567a09b9ad070361fc03c2840567_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;27&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;65&quot;: case &quot;68&quot;: case &quot;71&quot;: case &quot;77&quot;: case &quot;79&quot;: case &quot;81&quot;: case &quot;83&quot;: case &quot;91&quot;: case &quot;95&quot;: case &quot;98&quot;: case &quot;101&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;122&quot;: case &quot;129&quot;: case &quot;132&quot;: case &quot;133&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;149&quot;: case &quot;150&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;155&quot;: case &quot;156&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;164&quot;: case &quot;165&quot;: case &quot;166&quot;: case &quot;167&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;174&quot;: case &quot;180&quot;: case &quot;186&quot;: case &quot;193&quot;: case &quot;195&quot;: case &quot;198&quot;: case &quot;203&quot;: case &quot;204&quot;: case &quot;205&quot;: case &quot;206&quot;: case &quot;207&quot;: case &quot;208&quot;: case &quot;209&quot;: case &quot;212&quot;: case &quot;213&quot;: case &quot;215&quot;: case &quot;216&quot;: case &quot;217&quot;: case &quot;218&quot;: case &quot;219&quot;: case &quot;220&quot;: case &quot;221&quot;: case &quot;223&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;229&quot;: case &quot;230&quot;: case &quot;231&quot;: case &quot;236&quot;: case &quot;239&quot;: case &quot;240&quot;: case &quot;244&quot;: case &quot;245&quot;: case &quot;250&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;253&quot;: case &quot;255&quot;: case &quot;256&quot;: case &quot;259&quot;: case &quot;260&quot;: case &quot;261&quot;: case &quot;263&quot;: case &quot;267&quot;: case &quot;272&quot;: case &quot;273&quot;: case &quot;274&quot;: case &quot;276&quot;: case &quot;278&quot;: case &quot;283&quot;: case &quot;285&quot;: case &quot;287&quot;: case &quot;289&quot;: case &quot;291&quot;: case &quot;293&quot;: case &quot;295&quot;: case &quot;296&quot;: case &quot;297&quot;: case &quot;298&quot;: case &quot;299&quot;: case &quot;302&quot;: case &quot;305&quot;: case &quot;306&quot;: case &quot;307&quot;: case &quot;309&quot;: case &quot;310&quot;: case &quot;315&quot;: case &quot;316&quot;: case &quot;319&quot;: case &quot;320&quot;: case &quot;321&quot;: case &quot;322&quot;: case &quot;324&quot;: case &quot;325&quot;: case &quot;326&quot;: case &quot;328&quot;: case &quot;332&quot;: case &quot;336&quot;: case &quot;337&quot;: case &quot;338&quot;: case &quot;339&quot;: case &quot;340&quot;: case &quot;341&quot;: case &quot;342&quot;: case &quot;343&quot;: case &quot;345&quot;: case &quot;346&quot;: case &quot;350&quot;: case &quot;351&quot;: case &quot;353&quot;: case &quot;355&q

# %% [markdown]
# ## 8. Export Results

# %%
# Export transit deserts to CSV
transit_deserts = gdf[gdf['transit_desert'] == True][['GEOID', 'TDI_normalized', 'CPTA_normalized', 'transit_gap', 'lisa_cluster']]
print(f"Transit Desert Tracts ({len(transit_deserts)}):")
transit_deserts.sort_values('transit_gap', ascending=False).head(10)
# Out:
# Transit Desert Tracts (128):
#            GEOID  TDI_normalized  CPTA_normalized  transit_gap  \
# 181  42101028200       98.569234        41.276684    57.292550
# 44   42101020000      100.000000        43.193429    56.806571
# 154  42101009100       88.661392        36.699848    51.961544
# 142  42101039100       86.636214        36.539480    50.096734
# 102  42101020101       87.800645        38.229322    49.571324
# 179  42101028000       82.329026        34.411016    47.918010
# 69   42101018801       87.286641        39.389357    47.897284
# 120  42101014800       85.089173        38.302721    46.786452
# 265  42101017201       86.170918        39.841776    46.329142
# 119  42101014700       85.068363        39.714148    45.354215
#
#         lisa_cluster
# 181        High-High
# 44         High-High
# 154        High-High
# 142  Not Significant
# 102        High-High
# 179        High-High
# 69         High-High
# 120        High-High
# 265        High-High
# 119        High-High
